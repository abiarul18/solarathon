# %% [markdown]
# <a href="https://colab.research.google.com/github/abiarul18/solarathon/blob/master/Data_Analysis_with_Pandas_and_NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# path = pd.read_csv("C:/Users/2148034/OneDrive - Cognizant/Desktop/retail/transactions.csv")

# %%
# !ls -l C:/Users/2148034/OneDrive - Cognizant/Desktop/retail/transactions.csv

# %%
# !chmod a+r C:/Users/2148034/OneDrive - Cognizant/Desktop/retail/transactions.csv

# %%
# !pip install pandas

# %%
# C:\Pandas+Course+Resources\Pandas Course Resources\retail
# "C:\Pandas+Course+Resources\Pandas Course Resources\retail\transactions.csv"

# "C:\Users\2148034\OneDrive - Cognizant\Desktop\retail\transactions.csv"

# %%
# path = pd.read_csv("retail/transactions.csv")

# %%
# from google.colab import files


uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-6070230620fc> in <cell line: 4>()
#       2
#       3
# ----> 4 uploaded = files.upload()
#
# NameError: name 'files' is not defined

# %%
"""

import pandas as pd
import io

transactions= pd.read_csv(io.BytesIO(uploaded['transactions.csv']))
print(transactions)

"""

# %%
# transactions.shape

# %%
# transactions.index.max()

# %%
# transactions.dtypes

# %%
# "C:\Users\2148034\OneDrive - Cognizant\Desktop\retail\oil.csv"

# %%
# oil=pd.read_csv("C:/Users/2148034/OneDrive - Cognizant/Desktop/retail/oil.csv")

# %%
# https://drive.google.com/drive/folders/1mE0TIEf__iPTFr_DQKl_OycXQha43ckf?usp=drive_link

# %% [markdown]
# # DATAFRAME - INFO AND DESCRIBE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
transactions = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas+Course+Resources/Pandas Course Resources/retail/transactions.csv')

# %%
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
import pandas as pd

oil = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas+Course+Resources/Pandas Course Resources/retail/oil.csv')

# %%
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.head(10)
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
# 5  2013-01-08       93.21
# 6  2013-01-09       93.08
# 7  2013-01-10       93.81
# 8  2013-01-11       93.60
# 9  2013-01-14       94.27

# %%
oil.tail(5)
# Out:
#             date  dcoilwtico
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26

# %%
oil.sample(5)
# Out:
#             date  dcoilwtico
# 1113  2017-04-07       52.25
# 385   2014-06-24      106.64
# 256   2013-12-25         NaN
# 605   2015-04-28       57.05
# 541   2015-01-28       44.08

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
oil.describe()
# Out:
#         dcoilwtico
# count  1175.000000
# mean     67.714366
# std      25.630476
# min      26.190000
# 25%      46.405000
# 50%      53.190000
# 75%      95.660000
# max     110.620000

# %%
oil.describe(include="all")
# include argument includes other data types other than integers
# here data column with 'object' dt is included
# Out:
#               date   dcoilwtico
# count         1218  1175.000000
# unique        1218          NaN
# top     2013-01-01          NaN
# freq             1          NaN
# mean           NaN    67.714366
# std            NaN    25.630476
# min            NaN    26.190000
# 25%            NaN    46.405000
# 50%            NaN    53.190000
# 75%            NaN    95.660000
# max            NaN   110.620000

# %% [markdown]
# # EXPLORING A DATAFRAME - ASSIGNMENT

# %%
transactions = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas+Course+Resources/Pandas Course Resources/retail/transactions.csv')

# %%
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.head(10)
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903
# 6  2013-01-02          6          2143
# 7  2013-01-02          7          1874
# 8  2013-01-02          8          3250
# 9  2013-01-02          9          2940

# %%
transactions.isna().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %%
transactions.describe()
# Out:
#           store_nbr  transactions
# count  83488.000000  83488.000000
# mean      26.939237   1694.602158
# std       15.608204    963.286644
# min        1.000000      5.000000
# 25%       13.000000   1046.000000
# 50%       27.000000   1393.000000
# 75%       40.000000   2079.000000
# max       54.000000   8359.000000

# %%
transactions.describe(include="all")
# Out:
#               date     store_nbr  transactions
# count        83488  83488.000000  83488.000000
# unique        1682           NaN           NaN
# top     2017-08-15           NaN           NaN
# freq            54           NaN           NaN
# mean           NaN     26.939237   1694.602158
# std            NaN     15.608204    963.286644
# min            NaN      1.000000      5.000000
# 25%            NaN     13.000000   1046.000000
# 50%            NaN     27.000000   1393.000000
# 75%            NaN     40.000000   2079.000000
# max            NaN     54.000000   8359.000000

# %%
oil.columns=['date','price']

# here "oil price" is renamed to "price"

# %%
oil.head()
# Out:
#          date  price
# 0  2013-01-01    NaN
# 1  2013-01-02  93.14
# 2  2013-01-03  92.97
# 3  2013-01-04  93.12
# 4  2013-01-07  93.20

# %%
oil.date
# Out:
# 0       2013-01-01
# 1       2013-01-02
# 2       2013-01-03
# 3       2013-01-04
# 4       2013-01-07
#            ...
# 1213    2017-08-25
# 1214    2017-08-28
# 1215    2017-08-29
# 1216    2017-08-30
# 1217    2017-08-31
# Name: date, Length: 1218, dtype: object

# %%
# oil.oil price

# will get an syntax error as there is a space in column name
# so we can use bracket notation to access the column instead of dot notation
# or we can rename the column to "price" or "oil_price"

# %%
oil['price']
# Out:
# 0         NaN
# 1       93.14
# 2       92.97
# 3       93.12
# 4       93.20
#         ...
# 1213    47.65
# 1214    46.40
# 1215    46.46
# 1216    45.96
# 1217    47.26
# Name: price, Length: 1218, dtype: float64

# %%
# using double brackets we can get a dataframe of the column

oil[["price"]]
# Out:
#       price
# 0       NaN
# 1     93.14
# 2     92.97
# 3     93.12
# 4     93.20
# ...     ...
# 1213  47.65
# 1214  46.40
# 1215  46.46
# 1216  45.96
# 1217  47.26
#
# [1218 rows x 1 columns]

# %%
oil[['date','price']]
# Out:
#             date  price
# 0     2013-01-01    NaN
# 1     2013-01-02  93.14
# 2     2013-01-03  92.97
# 3     2013-01-04  93.12
# 4     2013-01-07  93.20
# ...          ...    ...
# 1213  2017-08-25  47.65
# 1214  2017-08-28  46.40
# 1215  2017-08-29  46.46
# 1216  2017-08-30  45.96
# 1217  2017-08-31  47.26
#
# [1218 rows x 2 columns]

# %%
oil['euro_price'] = oil['price']*1.1

oil
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.iloc[:5, :]
# Out:
#          date  price  euro_price
# 0  2013-01-01    NaN         NaN
# 1  2013-01-02  93.14     102.454
# 2  2013-01-03  92.97     102.267
# 3  2013-01-04  93.12     102.432
# 4  2013-01-07  93.20     102.520

# %%
oil.iloc[:5, [-1]]
# Out:
#    euro_price
# 0         NaN
# 1     102.454
# 2     102.267
# 3     102.432
# 4     102.520

# %%
oil.iloc[:5,-2:]
# Out:
#    price  euro_price
# 0    NaN         NaN
# 1  93.14     102.454
# 2  92.97     102.267
# 3  93.12     102.432
# 4  93.20     102.520

# %%
oil.loc[:5,'price']
# Out:
# 0      NaN
# 1    93.14
# 2    92.97
# 3    93.12
# 4    93.20
# 5    93.21
# Name: price, dtype: float64

# %%
oil.loc[:5,['price']]
# Out:
#    price
# 0    NaN
# 1  93.14
# 2  92.97
# 3  93.12
# 4  93.20
# 5  93.21

# %%
oil.loc[:5,['date','euro_price']]
# Out:
#          date  euro_price
# 0  2013-01-01         NaN
# 1  2013-01-02     102.454
# 2  2013-01-03     102.267
# 3  2013-01-04     102.432
# 4  2013-01-07     102.520
# 5  2013-01-08     102.531

# %%
# oil.loc[:5, ["date":"euro_price"]]

# can do slicing within the brackets

# %% [markdown]
# # ASSIGNMENT - ACCESSING DATAFRAME DATA

# %%
transactions.head()

# to remove 1st row from the data and get store_nbr and transactions column
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
# using ILOC
transactions.iloc[1:, 1:]
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
# using LOC
transactions.loc[1:, "store_nbr":"transactions"]
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %% [markdown]
# # DROPPING ROWS AND COLUMNS

# %%
oil.head()
# Out:
#          date  price  euro_price
# 0  2013-01-01    NaN         NaN
# 1  2013-01-02  93.14     102.454
# 2  2013-01-03  92.97     102.267
# 3  2013-01-04  93.12     102.432
# 4  2013-01-07  93.20     102.520

# %%
oil_euro = oil.drop('price',axis=1)

oil_euro
# Out:
#             date  euro_price
# 0     2013-01-01         NaN
# 1     2013-01-02     102.454
# 2     2013-01-03     102.267
# 3     2013-01-04     102.432
# 4     2013-01-07     102.520
# ...          ...         ...
# 1213  2017-08-25      52.415
# 1214  2017-08-28      51.040
# 1215  2017-08-29      51.106
# 1216  2017-08-30      50.556
# 1217  2017-08-31      51.986
#
# [1218 rows x 2 columns]

# %%
oil_euro = oil.drop(1, axis=0)

oil_euro
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# 5     2013-01-08  93.21     102.531
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1217 rows x 3 columns]
